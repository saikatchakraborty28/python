# %%
                                                               ASSIGNMENT NO :- 01
   



Q1. Write all the conventions being followed while declaring a variable.


SOLUTION..> 1.A variable name must start with a letter we can  use upper or lower case for it
              2.Here, we also can use underscore for declaring a variable name.
               3.but we can not use numbers and special character at the starting of letter such as 1num = 12,@a = apple
                     for example :- a = 12 , E = 34, _w = whale , _A = apple
            
            
            
            
            Q2. What will happen if we declare a restricted keyword as a variable?
            
            
            SOLUTION-> keywords are the words whose meanings has already been explain in the python program. They are used to define the syntax and structure of python program.
                      so, we can not declare keyword as a variable.It is possible that python will give error if we do do.
                
                
                Q3. Can we actually declare a string as a variable name?
                
                
                Solution-> No, in Python, you cannot declare a string as a variable name directly. According to Python's variable naming rules, variable names must follow certain conventions:

Variable names can only contain letters (a-z, A-Z), digits (0-9), and underscores (_).
Variable names must start with a letter or an underscore.
Variable names are case-sensitive, so "myVar" and "myvar" are considered different variables.
Variable names cannot be a reserved keyword or a built-in function name in Python.
Therefore, you cannot directly assign a string as a variable name in Python. Variable names should be meaningful and descriptive, helping to convey the purpose of the variable within the code.




                    Q4. Is it possible for us to declare “_” as a variable? If so, then write an example of it.
    
    
    
                     SOLUTION-> Yes, it is possible to declare a variable with the name "". In Python, the underscore character "" is a valid variable name. It can be used as a regular variable like any other valid variable name.

Here's an example of declaring a variable named "_" and assigning a value to it:

FOR EXAMPLE.
_ = 10
print(_)
In this example, we declare a variable "" and assign the value 10 to it. The value of the variable "" is then printed, which will output 10 in the console.






        Q5. Using an example, explain how the variables in python are dynamic in nature.
    
    
    
    
    
        SOLUTION->
Variables in Python are dynamic in nature, which means their data type can change during the execution of a program. Let's consider an example to understand this:

FOR EXAMPLE:
x = 5  # Assign an integer value to variable x
print(x)  # Output: 5

x = "Hello"  # Assign a string value to the same variable x
print(x)  # Output: Hello
In this example, we start by assigning the value 5 to the variable x. We then print the value of x, which gives the output 5.

Next, we assign the string "Hello" to the same variable x. Since Python allows variables to be reassigned with different data types, the variable x now holds the value "Hello".

Finally, we print the value of x again, which now gives the output "Hello".

This demonstrates the dynamic nature of variables in Python. The same variable x can be assigned different data types at different points in the program. Python determines the data type of a variable dynamically based on the value it is currently holding.
